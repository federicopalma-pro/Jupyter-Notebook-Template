# %% [markdown]
# # Example Notebook
#
# This is an example notebook to test the project setup with UV and Jupyter.

# %%
# Import base libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Setup completed successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# Setup completed successfully!
# Pandas version: 2.2.3
# NumPy version: 2.1.3

# %%
# Plotting test
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='sin(x)')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('Test Plot with Matplotlib')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Test with pandas
data = {
    'x': np.random.randn(100),
    'y': np.random.randn(100),
    'category': np.random.choice(['A', 'B', 'C'], 100)
}

df = pd.DataFrame(data)
print("Dataframe created:")
print(df.head())
print(f"\nShape: {df.shape}")
print("\nDescription:")
print(df.describe())
# Out:
# Dataframe created:
#           x         y category
# 0  1.146117 -0.200025        A
# 1  0.941618 -0.630755        B
# 2 -1.107106  0.780237        C
# 3  1.023915 -0.883669        B
# 4 -0.349874  2.265969        A
#
# Shape: (100, 3)
#
# Description:
#                 x           y
# count  100.000000  100.000000
# mean     0.105073   -0.054825
# std      0.913170    1.007433
# min     -2.043298   -3.027701
# 25%     -0.482243   -0.711400
# 50%      0.266599   -0.114713
# 75%      0.760596    0.594173
# max      2.653459    2.354968

# %%
# Test with seaborn
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
sns.scatterplot(data=df, x='x', y='y', hue='category')
plt.title('Scatter plot with Seaborn')

plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='category', y='x')
plt.title('Box plot with Seaborn')

plt.tight_layout()
plt.show()

# %%
# Test importing our utilities
import sys
sys.path.append('../src')

from utils import create_sample_data, analyze_data, print_analysis

# Create sample data using our utility function
sample_df = create_sample_data(50)
print("Sample data created with our utility:")
print(sample_df.head())

# Analyze the data
analysis = analyze_data(sample_df)
print("\nData Analysis:")
print_analysis(analysis)
# Out:
# Sample data created with our utility:
#    id   value_a   value_b category       date
# 0   1  0.496714  0.151898        Y 2024-01-01
# 1   2 -0.138264  1.620484        Y 2024-01-02
# 2   3  0.647689  0.077476        Z 2024-01-03
# 3   4  1.523030  4.334146        Y 2024-01-04
# 4   5 -0.234153  1.479484        Z 2024-01-05
#
# Data Analysis:
# Dataset shape: (50, 5)
#
# Missing values:
#
# Numeric variables summary:
#   id: mean=25.50
#   value_a: mean=-0.23
#   value_b: mean=0.92
#
# Categorical variables:
#   category: ['X', 'Y', 'Z']
